# %%
# Load packages
import pandas as pd

# %%
##1# defining the url for the site
base_site = 'https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population'

##2# make (request, get, and parser) in one step using pandas function that called read_html
tables = pd.read_html(base_site)
len(tables)
# Out:
# 2

# %%
primary_table = tables[0]
primary_table
# Out:
#     Rank                 Country / Dependency    Region  Population  \
# 0      –                                  NaN     World  7926258000
# 1      1                                China      Asia  1412600000
# 2      2                                India      Asia  1387349502
# 3      3                        United States  Americas   333129631
# 4      4                         Indonesia[b]      Asia   271350000
# ..   ...                                  ...       ...         ...
# 237    –                   Niue (New Zealand)   Oceania        1549
# 238    –                Tokelau (New Zealand)   Oceania        1501
# 239  195                         Vatican City    Europe         825
# 240    –  Cocos (Keeling) Islands (Australia)   Oceania         573
# 241    –    Pitcairn Islands (United Kingdom)   Oceania          40
#
#      % of world         Date Source (official or from the United Nations)  \
# 0           NaN  28 Jan 2022                             UN projection[1]
# ...

# %%
primary_table.columns
# Out:
# Index(['Rank', 'Country / Dependency', 'Region', 'Population', '% of world',
#        'Date', 'Source (official or from the United Nations)', 'Notes'],
#       dtype='object')

# %%
primary_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 8 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Rank                                          242 non-null    object
#  1   Country / Dependency                          241 non-null    object
#  2   Region                                        242 non-null    object
#  3   Population                                    242 non-null    int64
#  4   % of world                                    0 non-null      float64
#  5   Date                                          242 non-null    object
#  6   Source (official or from the United Nations)  242 non-null    object
#  7   Notes                                         34 non-null     object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 15.2+ KB
